# %%
import pandas as pd

# %%
df = pd.read_csv('./all_jobs.csv')

# %%
df['id'] = df.link.apply(lambda l: l.rsplit('/', maxsplit=1)[1])

# %%
df.company.value_counts().head(n=10)
# Out:
# company
# Alignerr           72
# Capital One        50
# G2i                30
# Speechify          15
# OpenAI             12
# Thomson Reuters    11
# SentinelOne        11
# Scale AI           10
# Samsara            10
# Coinbase           10
# Name: count, dtype: int64

# %%
df[df.company == 'Alignerr'].iloc[0].link
# Out:
# 'https://builtin.com/job/software-engineer-swift-ai-training-freelance-remote/4746300'

# %%
df = df[df.company != 'Alignerr']

# %%
df[df.company == 'Capital One'].iloc[0].link
# Out:
# 'https://builtin.com/job/distinguished-ai-engineer/8162528'

# %%
(df.title + ' ' + df.company).value_counts().head()
# Out:
# Lead AI Engineer (AI Foundations, LLM Core and Agentic AI) Capital One           7
# Senior Lead AI Engineer (AI Foundations, LLM Core and Agentic AI) Capital One    6
# Staff Fullstack Engineer (Python/Vue.js), AI Engineering: Duo Chat GitLab        5
# Senior Site Reliability Engineer — AI Studio (Inference Platform) Nebius         5
# Applied AI Engineer Percepta AI                                                  4
# Name: count, dtype: int64

# %%
df = df.drop_duplicates(subset=['title', 'company'])

# %%
df.to_csv('all_jobs_dedup.csv', index=False)

# %%
df.title.str.lower().apply(lambda s: ('ai' in s) and ('engineer' in s)).mean()
# Out:
# np.float64(0.9664804469273743)

# %%
df.title.str.lower().str.contains(r'ai.*engineer').mean()
# Out:
# np.float64(0.5754189944134078)

# %%
df.title.str.lower().str.contains(r'ai\s+engineer').mean()
# Out:
# np.float64(0.32625698324022345)

# %%
df_ai = df[df.title.str.lower().str.contains(r'ai\s+engineer')]

# %%
df_ai
# Out:
#                                                   title  \
# 5      AI Engineer (Libra - Legal AI Assistant) (m/f/d)
# 6     Senior AI Engineer (Libra - Legal AI Assistant...
# 7                          (Senior) AI Engineer (m/f/d)
# 8                                  Customer AI Engineer
# 9                                           AI Engineer
# ...                                                 ...
# 1076                                Applied AI Engineer
# 1096                                        AI Engineer
# 1108                                 Senior AI Engineer
# 1126         Senior AI Engineer – Agentic Platform Lead
# 1132                              Principal AI Engineer
#
#                       company              location            work_type  \
# 5              Wolters Kluwer           Berlin, DEU            In-Office
# 6              Wolters Kluwer           Berlin, DEU            In-Office
# 7          Flip (getflip.com)          30 Locations  In-Office or Remote
# 8                       telli           Berlin, DEU            In-Office
# 9                       Flank           Berlin, DEU            In-Office
# ...                       ...                   ...                  ...
# 1076                 Outsmart           2 Locations            In-Office
# 1096  Capsule (capsule.video)  Los Angeles, CA, USA            In-Office
# 1108                 WEX Inc.          13 Locations  In-Office or Remote
# 1126     Voyager Technologies           3 Locations            In-Office
# 1132                    Kizen  Los Angeles, CA, USA               Hybrid
#
#              level        compensation  \
# 5        Mid level                 NaN
# 6     Senior level                 NaN
# 7     Senior level                 NaN
# 8        Mid level                 NaN
# 9     Senior level                 NaN
# ...            ...                 ...
# 1076  Senior level                 NaN
# 1096     Mid level                 NaN
# 1108  Senior level  140K-186K Annually
# 1126  Senior level  165K-250K Annually
# 1132  Senior level  250K-412K Annually
#
#                                                    link       id
# 5           https://builtin.com/job/ai-engineer/8273513  8273513
# 6     https://builtin.com/job/senior-ai-engineer-lib...  8276358
# 7     https://builtin.com/job/senior-ai-engineer-m-f...  7203472
# 8     https://builtin.com/job/customer-engineer-ai/7...  7643852
# 9           https://builtin.com/job/ai-engineer/7132625  7132625
# ...                                                 ...      ...
# 1076  https://www.builtinla.com/job/applied-ai-engin...  8250680
# 1096  https://www.builtinla.com/job/ai-engineer/7107575  7107575
# 1108  https://www.builtinla.com/job/senior-machine-l...  7064866
# 1126  https://www.builtinla.com/job/senior-ai-engine...  8019906
# 1132  https://www.builtinla.com/job/principal-ai-eng...  7269462
#
# [292 rows x 8 columns]

# %%
df_ai.work_type.value_counts()
# Out:
# work_type
# In-Office              122
# Remote                  83
# Hybrid                  44
# In-Office or Remote     28
# Remote or Hybrid        13
# Name: count, dtype: int64

# %%
df_ai.level.value_counts()
# Out:
# level
# Senior level     161
# Mid level        100
# Junior            17
# Expert/Leader      8
# Internship         4
# Entry level        2
# Name: count, dtype: int64
